# %%
# !rm -rf AtomML-Course
# !git clone https://github.com/AMLS-PRG/AtomML-Course
# Out:
# Cloning into 'AtomML-Course'...
# remote: Enumerating objects: 2751, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 2751 (delta 87), reused 21 (delta 21), pack-reused 2625 (from 1)
# Receiving objects: 100% (2751/2751), 47.27 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (1356/1356), done.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file_path = "AtomML-Course/module-5/02-Training-machine-learning-potential-MLP/Trained-MLPs/lcurve.out"

# %%
colnames = [
    "step", "rmse_val", "rmse_trn", "rmse_e_val", "rmse_e_trn",
    "rmse_f_val", "rmse_f_trn", "lr"
]


df = pd.read_csv(
    file_path,
    delim_whitespace=True,
    comment="#",
    names=colnames,
    engine="python"
)


df = df.astype(float)

plt.figure(figsize=(14, 6))

# ------- Energy RMSE Plot -------
plt.subplot(1, 2, 1)
plt.plot(df["step"], df["rmse_e_val"], label="Validation", color="tab:blue")
plt.plot(df["step"], df["rmse_e_trn"], label="Train", color="tab:orange")
plt.yscale("log")
plt.xlabel("Training Step")
plt.ylabel("Energy RMSE (eV)")
plt.title("Log-scale Energy RMSE")
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend()

# ------- Force RMSE Plot -------
plt.subplot(1, 2, 2)
plt.plot(df["step"], df["rmse_f_val"], label="Validation", color="tab:green")
plt.plot(df["step"], df["rmse_f_trn"], label="Train", color="tab:red")
plt.yscale("log")
plt.xlabel("Training Step")
plt.ylabel("Force RMSE (eV/Å)")
plt.title("Log-scale Force RMSE")
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-69ef4dcfdaf9>:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
